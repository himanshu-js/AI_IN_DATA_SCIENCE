# %% [markdown]
# <a href="https://colab.research.google.com/github/himanshu-js/AI_IN_DATA_SCIENCE/blob/main/Module%201/Ch_1_Basic_of_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hello World Program

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ## VARIABLES
#
#
#
# *   Variables in Python are simply labels or pointers that point to an object in memory
# *  Store the memeory address of the value
#
#
# #### RULES
#
# *   Start with letter or underscore
# *   Cannot start with number
# *   No soaces
# *   Keyword cannot be used

# %%
x = 2

# %%
print(x)
# Out:
# 2

# %%
# type - tells the data type
print(type(x))
# Out:
# <class 'int'>

# %% [markdown]
# ## DATA TYPE
#
#
#
#
#
# *  Text Type:	str
# *  Set Types:	set, frozenset
# *  Boolean Type:	bool
# *  None Type:	NoneType
# *  Numeric Types:	int, float, complex
# *  Sequence Types:	list, tuple, range

# %%
a = 10
print(type(a))# type method is used to get the type of the data
# Out:
# <class 'int'>

# %%
string = 'Python'
print(type(a))
# Out:
# <class 'str'>

# %%
num = 2.09
print(type(num))
# Out:
# <class 'float'>

# %%
a = True
print(type(a))
# Out:
# <class 'bool'>

# %%
empty = ''
print(type(empty))
# Out:
# <class 'str'>

# %%
x = None
print(type(x))
# Out:
# <class 'NoneType'>

# %%
a = []
print(type(a))
# Out:
# <class 'list'>

# %% [markdown]
# ## TYPE CASTING
#
#
#
# *   Converting the data from one type to another
# *   str() - used for string conversion
# *   int() - used for integer conversion
# *   float() - used for float conversion

# %%
a = '10'
print(type(a))
# Out:
# <class 'str'>

# %%
print(type(int(a))) # using int() method to convert string into the integer
# Out:
# <class 'int'>

# %%
print(type(float(a))) # using the float() method to convert int to float
# Out:
# <class 'float'>

# %% [markdown]
# ## OPERATORS
#
# Performs operations on the data
#
#
#
# *   Arithematic Operator
# *   Assignment Operator
# *   Comparison Operator
# *   Logical Operator

# %%
# Arithematic Operators
# +,-,*,**,//,/,%

a = 10
b = 20
c = a+b
print(c)
# Out:
# 30

# %%
a = 10
b = 20
c = b-a
print(c)
# Out:
# 10

# %%
a = 10
b = 20
c = a*b
print(c)
# Out:
# 200

# %%
a = 10
b = 20
c = b / a
print(c)
# Out:
# 2.0

# %%
a = 2
b = 3
c = a**b
print(c)
# Out:
# 8

# %%
print(9 % 2) # return the remainder
# Out:
# 1

# %%
print(9 // 2) # return the integer part only
# Out:
# 4

# %% [markdown]
# ## ASSIGNMENT OPERATOR

# %%
# =,+=,-=,/=,*=,//=,**=

# %%
a = 10
print(a)
# Out:
# 10

# %%
sum = 10
sum += 20 # sum = sum + 20
print(sum)
#
# Out:
# 30

# %% [markdown]
# ## COMPARISON OPERATOR

# %%
# ==,!=,<=,>=,<,>


a = 10
b = 5

print(a == b)
# Out:
# False

# %%
print(a > b)
# Out:
# True

# %%
print(a < b)
# Out:
# False

# %%
print(a != b)
# Out:
# True

# %% [markdown]
# ## LOGICAL OPERATOR

# %%
# and
# or
# not

# %%
# and
# if both conditons are true then true if not then false
a = 10
b = 15

print(a > 5  and b < 20)
# Out:
# True

# %%
# or
# one must be true to be true if not then false

print(a > 5  or  b < 8)
# Out:
# True

# %%
# not
# make true false and false true

a = True
not(a)
# Out:
# False
